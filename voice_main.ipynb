# %% [markdown]
# <a href="https://colab.research.google.com/github/sunnys-lab/GC_2019_Track3_Voice/blob/master/voice_main.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
from google.colab import drive
drive.mount('/content/drive/')
# Out:
# Mounted at /content/drive/

# %%
# !ls '/content/drive/My Drive'
# Out:
# 'Block chain Study'   GC_2019_Track3_Voice  'Go Backup'

# %%
# 01. 음성파일 들어보기

import IPython.display as ipd
from scipy.io import wavfile

# 음성파일 경로 지정
data_dir = '/content/drive/My Drive/GC_2019_Track3_Voice'
train_audio_path = data_dir + '/train/'
filename = 't3_audio_0001.wav'

# 음성 데이터 읽어오기
sample_rate, samples = wavfile.read(str(train_audio_path) + filename)

# Player 실행
ipd.Audio(str(train_audio_path) + filename)
# Out:
#                 <audio controls="controls" >
#                     <source src="data:audio/x-wav;base64,..." type="audio/x-wav" />
#                     Your browser does not support the audio element.
#                 </audio>

# %%
#02. 음성파일
